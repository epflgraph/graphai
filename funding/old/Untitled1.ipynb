# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import matplotlib.pyplot as plt

from interfaces.db import DB
from funding.data_processing import build_time_series, time_period_range
from funding.visualization import plot_df

# %%
db = DB()

# %%
min_date = "1990-01-01"
max_date = "2022-01-01"

# %%
concept_ids = [1164, 11657, 12266, 1944675, 19541494, 26162030, 28249265, 4835266, 564204, 604727]

df = build_time_series(min_date, max_date, concept_ids, debug=False)

# %%
plot_df(df)
